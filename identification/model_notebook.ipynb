# %% [markdown]
# # Import Required Libraries
# This cell imports necessary libraries for model creation, data preprocessing, and evaluation.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import json
import numpy as np
from tensorflow.keras.models import load_model
import os
from glob import glob
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Define Base Model
# This cell defines the base VGG16 model and adds custom layers for classification.

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
for layer in base_model.layers:
    layer.trainable = False

x = Flatten()(base_model.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(268, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=x)
model.compile(optimizer=Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Data Generators
# ##### Dataset donwloading link : https://universe.roboflow.com/iit-jammu-elhdf/cow-face-2qral

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    "./train",
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=16
)

train_classes = train_generator.class_indices.keys()

val_generator = val_datagen.flow_from_directory(
    "./valid",
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=16,
    classes=list(train_classes)
)

num_classes = len(train_generator.class_indices)
# Out:
# Found 3330 images belonging to 268 classes.
# Found 641 images belonging to 268 classes.

# %% [markdown]
# # Train Model
# This cell trains the model using the training and validation data.

# %%
# model.fit(
#       train_generator,
#       validation_data=val_generator,
#       epochs=50
#   )

# %% [markdown]
# # Save Model
# This cell saves the trained model to a file.

# %%
# model.save('muzzle.keras')

# %% [markdown]
# # Load Model and Create Embedding Model
# This cell loads the saved model and creates an embedding model for feature extraction.

# %%
model = load_model("muzzle.keras")
embedding_model = Model(inputs=model.input, outputs=model.layers[-2].output)

# %% [markdown]
# ## Function to return embeddings from a muzzle image

# %%
def get_embedding(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)
    embedding = embedding_model.predict(img_array)
    return embedding.flatten()

# %% [markdown]
# # Function to build a database that contains the embeddings of each cow

# %%
def build_embedding_database(train_dir="./train"):
    database = {"embeddings": [], "labels": []}
    for class_name in os.listdir(train_dir):
        class_path = os.path.join(train_dir, class_name)
        if not os.path.isdir(class_path): continue
        for img_path in glob(os.path.join(class_path, "*.jpg")):
            emb = get_embedding(img_path)
            database["embeddings"].append(emb)
            database["labels"].append(class_name)
    return database

# %% [markdown]
# ### Building the database and saving it as a json from

# %%
def save_database_as_json(database, filename="embedding_database.json"):
    json_ready = {
        "labels": database["labels"],
        "embeddings": [emb.tolist() for emb in database["embeddings"]]
    }
    with open(filename, "w") as f:
        json.dump(json_ready, f)
    print(f"✅ Base sauvegardée dans {filename}")

def load_database_from_json(filename="embedding_database.json"):
    with open(filename, "r") as f:
        data = json.load(f)
    return {
        "labels": data["labels"],
        "embeddings": [np.array(emb) for emb in data["embeddings"]]
    }

# %%
# database = build_embedding_database("./train")
# save_database_as_json(database, filename="embedding_database.json")
        # if you saved the dataset already, use this for loading:  
database = load_database_from_json("embedding_database.json")

# %% [markdown]
# # Predict Identity
# This cell defines a function to predict the identity of a cow based on an image and the embedding database.

# %%
def predict_identity(img_path, database, seuil=0.7):
    query_emb = get_embedding(img_path)
    sims = cosine_similarity([query_emb], database["embeddings"])[0]
    best_score = np.max(sims)
    best_index = np.argmax(sims)
    
    if best_score < seuil:
        return "INCONNUE", best_score
    else:
        return database["labels"][best_index], best_score

# %% [markdown]
# ## Model testing on test data

# %%
def evaluate_on_test_folder(test_dir, database, seuil=0.7):
    y_true = []
    y_pred = []

    for true_label in os.listdir(test_dir):
        class_path = os.path.join(test_dir, true_label)
        if not os.path.isdir(class_path):
            continue

        image_paths = glob(os.path.join(class_path, "*.jpg"))
        for img_path in image_paths:
            predicted_label, score = predict_identity(img_path, database, seuil=seuil)

            y_true.append(true_label)
            y_pred.append(predicted_label)

            print(f"{os.path.basename(img_path)} → vrai: {true_label}, prédit: {predicted_label}, score: {score:.2f}")

    accuracy = accuracy_score(y_true, y_pred)
    print(f"\n✅ Accuracy sur le dossier de test : {accuracy * 100:.2f}%")

    return accuracy, y_true, y_pred

# %%
test_dir = "./test"
accuracy, y_true, y_pred = evaluate_on_test_folder(test_dir, database)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# cattle_0100_DSCF3856_jpg.rf.911d88a85a9c6a35411117b7a52849cd.jpg → vrai: cattle_0100, prédit: cattle_0100, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# cattle_0400_DJI_0129_jpg.rf.059cf1bf9a13edcdf2e34af2aac50ce5.jpg → vrai: cattle_0400, prédit: cattle_0300, score: 0.87
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# cattle_0400_DSCF3894_jpg.rf.a2c62fcadc581b97ba4cacd30764285e.jpg → vrai: cattle_0400, prédit: cattle_0400, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# cattle_0500_DSCF3905_jpg.rf.d103c1704a940aace6ff240ed893215d.jpg → vrai: cattle_0500, prédit: cattle_0500, score: 0.99
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# cattle_0600_DSCF3916_jpg.rf.4c9618a909f1379db66ab412dd969167.jpg → vrai: cattle_0600, prédit: cattle_0600, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# cattle_0600_DSCF3923_jpg.rf.1a7081c06b2c9508a75657edf4c59733.jpg → vrai: cattle_0600, prédit: cattle_0600, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# cattle_0700_DJI_0148_jpg.rf.b22a5248a647bc26df5d1d1aa42133ca.jpg → vrai: cattle_0700, prédit: cattle_0700, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# cattle_0800_DJI_0162_jpg.rf.8769e467dceb02a68b96fba3fc2fd742.jpg → vrai: cattle_0800, prédit: cattle_0800, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# cattle_0800_DSCF3941_jpg.rf.a23c3f9bdbc6bdd337060439b5be52f6.jpg → vrai: cattle_0800, prédit: cattle_0800, score: 0.99
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# cattle_0800_DSCF3946_jpg.rf.9f18466e621d30efd80c278388694cfb.jpg → vrai: cattle_0800, prédit: cattle_0800, score: 0.98
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# cattle_0800_DSCF3947_jpg.rf.a40ba3d7ba61c6135492f85f81fe8009.jpg → vrai: cattle_0800, prédit: cattle_0800, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# cattle_0900_DSCF3958_jpg.rf.5feda8b2fff7bd89a8460c180870770e.jpg → vrai: cattle_0900, prédit: cattle_0900, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# cattle_1000_DSCF3961_jpg.rf.6eacbd93c9c17b77e78c91e2db84f5ef.jpg → vrai: cattle_1000, prédit: cattle_1000, score: 0.98
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# cattle_1000_DSCF3968_jpg.rf.28a40dc676ff8639fecff815f929a115.jpg → vrai: cattle_1000, prédit: cattle_1000, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# cattle_1200_DSCF3986_jpg.rf.f23dd3ff91462dc03ee8215e29634dcc.jpg → vrai: cattle_1200, prédit: cattle_1200, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# cattle_1200_DSCF3988_jpg.rf.6c1cac1ec1729f81290894770a980ad6.jpg → vrai: cattle_1200, prédit: cattle_1200, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# cattle
score: 0.99
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# cattle_9634_DSCF8595_jpg.rf.8528abcb04ffa1db284d8761dc7eb880.jpg → vrai: cattle_9634, prédit: cattle_9634, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# cattle_9634_DSCF8605_jpg.rf.a5fa3352867e3304ffc13c845b4203a4.jpg → vrai: cattle_9634, prédit: cattle_9634, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# cattle_9634_DSCF8612_jpg.rf.cf1369802e61ff84b31e53c7aed582a5.jpg → vrai: cattle_9634, prédit: cattle_9634, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# cattle_9634_DSCF8619_jpg.rf.6e6744ea0d9d6db73410f6d662efc966.jpg → vrai: cattle_9634, prédit: cattle_9634, score: 0.99
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# cattle_9736_DSCF8524_jpg.rf.8a444ffc7447e21e235ee7b9b2a7c210.jpg → vrai: cattle_9736, prédit: cattle_9736, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# cattle_9736_DSCF8530_jpg.rf.ba54838854bcac9085ba9e834eefa903.jpg → vrai: cattle_9736, prédit: cattle_9736, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# cattle_9742_DSCF8522_jpg.rf.1ef7b841965fbdeee9ff1a71223f78e6.jpg → vrai: cattle_9742, prédit: cattle_9742, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# cattle_9742_DSCF8525_jpg.rf.12ce2ad099ab53ea62f5afe52759e8c2.jpg → vrai: cattle_9742, prédit: cattle_9742, score: 1.00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# cattle_9798_DSCF8503_jpg.rf.21413db3459565036ec230f3351f560f.jpg → vrai: cattle_9798, prédit: cattle_9798, score: 0.98
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# cattle_9798_DSCF8505_jpg.rf.36fd8d58b3bc90de9dd42febafbf445e.jpg → vrai: cattle_9798, prédit: cattle_9798, score: 0.98
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# cattle_9798_DSCF8513_jpg.rf.2b4847384a35ac5f2aa1138e87398509.jpg → vrai: cattle_9798, prédit: cattle_9798, score: 0.99
#
# ✅ Accuracy sur le dossier de test : 98.78%

# %% [markdown]
# # Add New Cow to Database
# This cell defines a function to add a new cow's images to the embedding database.

# %%
def add_new_cow_to_database(cow_id, image_paths, database):
    for img_path in os.listdir(image_paths):
        emb = get_embedding(os.path.join(image_paths, img_path))
        database["embeddings"].append(emb)
        database["labels"].append(cow_id)

# %%
add_new_cow_to_database("cow_test", "./train/cattle_new", database)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step

# %% [markdown]
# ## To make an individial prediction

# %%
img_path = "test/cattle_new/cropped_3.jpg"
label, score = predict_identity(img_path, database)

print(f"🧠 Vache prédite : {label} (confiance : {score:.2f})")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# 🧠 Vache prédite : cow_test (confiance : 0.92)

# %% [markdown]
# ## Export to tar

# %%
import tarfile
import os
import tensorflow as tf

input_model = '../cow_api/utils/muzzle.keras'   
export_path = './export_temp/1/muzzle.keras'    
output_file = 'model.tar.gz'

if not os.path.exists(export_path):
    print(f"Chargement de {input_model}...")
    model = tf.keras.models.load_model(input_model)
    
    print("Sauvegarde au format SavedModel...")
    model.save(export_path)
else:
    print("Le dossier d'export existe déjà, on passe à la compression.")

print(f"Création de {output_file}...")
with tarfile.open(output_file, "w:gz") as tar:
    tar.add(export_path, arcname='1') 

print("Succès ! Le fichier model.tar.gz est prêt.")
# Out:
# Le dossier d'export existe déjà, on passe à la compression.
# Création de model.tar.gz...
# Succès ! Le fichier model.tar.gz est prêt.
